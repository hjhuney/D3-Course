# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Dictionaries

# %%
# https://teamcolorcodes.com/ncaa-color-codes/sec-team-color-codes/

sec_color_dict = {
    'ALA': '#9e1b32', 'MISS': '#14213D', 'MIZ': '#F1B82D', 'SC': '#000000',
    'VAN': '#866d4b', 'TA&M': '#500000', 'LSU': '#461D7C', 'AUB': '#0C2340', 
    'UGA': '#BA0C2F', 'FLA': '#0021A5', 'MSST': '#660000', 'TENN': '#FF8200', 
    'ARK': '#9D2235', 'UK': '#0033a0'
}

# %%
sec_name_dict = {
    'ALA': 'Alabama', 'MISS': 'Ole Miss', 'MIZ': 'Missouri', 'SC': 'South Carolina',
    'VAN': 'Vanderbilt', 'TA&M': 'Texas A&M', 'LSU': 'LSU', 'AUB': 'Auburn', 
    'UGA': 'Georgia', 'FLA': 'Florida', 'MSST': 'Miss State', 'TENN': 'Tennessee', 
    'ARK': 'Arkansas', 'UK': 'Kentucky'    
}

# %%
conf_dict = {
    'SEC': ['ALA', 'MISS', 'MIZ', 'SC', 'VAN', 'TA&M', 'LSU', 'AUB', 'UGA', 'FLA', 'MSST', 'TENN', 'ARK', 'UK'],
    'Big10': ['OSU', 'PUR', 'NW', 'MSU'], 
    'ACC': ['NCST', 'CLEM'], 
    'Pac12': ['WSU'], 
    'Big12': ['OKLA', 'OKST', 'TEX']
}

inv_conf_dict = {v: k for k, values in conf_dict.items() for v in values}

# %% [markdown]
# # Dataframe

# %%
df = pd.read_csv('CFB_QBs_2018.csv')

df['Conference'] = df['Team'].map(inv_conf_dict)
df['TeamName'] = df['Team'].map(sec_name_dict)
df['TeamColor'] = df['Team'].map(sec_color_dict)
df['TennColor'] = '#74ABD6'


df['Player'] = df['Player'].str.split(',', expand=True)[0]

df['YPC'] = np.round(df['Yards'] / df['Completions'],1)
df['AttemptsPerINT'] = np.round(df['Attempts'] / df['INTs'],1)
df['INTModYards'] = df['Yards'] - (df['INTs'] * 50)
df['INTModYardsPerAtt'] = np.round(df['INTModYards'] / df['Attempts'],2)
df['AttemptsPerSack'] = np.round((df['Attempts'] + df['SacksTaken']) / df['SacksTaken'], 2)

df = df.drop(['Rank'], axis=1)


df = df[['Player', 'Team', 'TeamName', 'TeamColor', 'TennColor', 'Conference', 'Completions', 'Attempts',
       'CompletionPct', 'Yards', 'YPA', 'YPC', 'Long', 'TDs', 'INTs', 'SacksTaken',
       'QBRating', 'AttemptsPerINT', 'INTModYards', 'INTModYardsPerAtt', 'AttemptsPerSack']]

# df.columns = ['Player', 'Team', 'Conference', 'Completions', 'Attempts',
#        'Completion %', 'Yards', 'YPA', 'YPC', 'Long', 'TDs', 'INTs', 'Attempts per INT','Sacks Taken',
#        'QB Rating']

# %%
df.columns
# Out:
# Index(['Player', 'Team', 'TeamName', 'TeamColor', 'Conference', 'Completions',
#        'Attempts', 'CompletionPct', 'Yards', 'YPA', 'YPC', 'Long', 'TDs',
#        'INTs', 'SacksTaken', 'QBRating', 'AttemptsPerINT', 'INTModYards',
#        'INTModYardsPerAtt', 'AttemptsPerSack'],
#       dtype='object')

# %%
df.head()
# Out:
#              Player  Team TeamName TeamColor Conference  Completions  \
# 0    Dwayne Haskins   OSU      NaN       NaN      Big10          373
# 1   Gardner Minshew   WSU      NaN       NaN      Pac12          468
# 2      Kyler Murray  OKLA      NaN       NaN      Big12          260
# 3  Taylor Cornelius  OKST      NaN       NaN      Big12          288
# 4    Tua Tagovailoa   ALA  Alabama   #9e1b32        SEC          245
#
#    Attempts  CompletionPct  Yards   YPA   YPC  Long  TDs  INTs  SacksTaken  \
# 0       533           70.0   4831   9.1  13.0    78   50     8          20
# 1       662           70.7   4779   7.2  10.2    89   38     9          13
# 2       377           69.0   4361  11.6  16.8    86   42     7          18
# 3       485           59.4   3978   8.2  13.8    64   32    13          32
# 4       355           69.0   3966  11.2  16.2    81   43     6          13
#
#    QBRating  AttemptsPerINT  INTModYards  INTModYardsPerAtt  AttemptsPerSack
# 0     174.1            66.6         4431               8.31            27.65
# 1     147.6            73.6         4329               6.54            51.92
# 2     199.2            53.9         4011              10.64            21.94
# 3     144.7            37.3         3328               6.86            16.16
# 4     199.5            59.2         3666              10.33            28.31

# %%
df.columns
# Out:
# Index(['Player', 'Team', 'Conference', 'Completions', 'Attempts',
#        'CompletionPct', 'Yards', 'YPA', 'Long', 'TDs', 'INTs', 'SacksTaken',
#        'QBRating', 'TeamColor', 'YPC', 'AttemptsPerINT', 'INTModYards',
#        'INTModYardsPerAtt', 'AttemptsPerSack'],
#       dtype='object')

# %%
df.sort_values(by=['AttemptsPerINT'], ascending=False)[:25]
# Out:
#                  Player  Team   TeamName TeamColor Conference  Completions  \
# 159         Drew Eckels   WKU        NaN       NaN        NaN           50
# 143          Shai Werts  GASO        NaN       NaN        NaN           69
# 138      Mike Glass III   EMU        NaN       NaN        NaN           72
# 154          Zeb Noland   ISU        NaN       NaN        NaN           70
# 87        Peyton Bender    KU        NaN       NaN        NaN          183
# 21      Trevor Lawrence  CLEM        NaN       NaN        ACC          259
# 9            Mason Fine   UNT        NaN       NaN        NaN          303
# 150   Christian Chapman  SDSU        NaN       NaN        NaN           51
# 89        Tyler Wiegers   EMU        NaN       NaN        NaN          171
# 94        Holton Ahlers   ECU        NaN       NaN        NaN          127
# 12     Marcus McMaryion  FRES        NaN       NaN        NaN          293
# 20         Sam Ehlinger   TEX        NaN       NaN      Big12          275
# 85           Riley Neal  BALL        NaN       NaN        NaN          194
# 86   Jarrett Guarantano  TENN  Tennessee   #FF8200        SEC          153
# 122      Chris Reynolds  CHAR        NaN       NaN        NaN          101
# 126        Conor Blount  ORST        NaN       NaN        NaN           95
# 35           Joe Burrow   LSU        LSU   #461D7C        SEC          219
# 59          Gus Ragland  M-OH        NaN       NaN        NaN          226
# 41      Jarrett Stidham   AUB     Auburn   #0C2340        SEC          224
# 1       Gardner Minshew   WSU        NaN       NaN      Pac12          468
# 142      Cordale Grundy  UTSA        NaN       NaN        NaN          111
# 145       Davis Shanley   WKU        NaN       NaN        NaN           96
# 134     Michael Collins   TCU        NaN       NaN        NaN           79
# 132      Jonathan Banks  TULN        NaN       NaN        NaN           72
# 13          Jordan Love   USU        NaN       NaN        NaN          267
#
#      Attempts  CompletionPct  Yards  YPA   YPC  Long  TDs  INTs  SacksTaken  \
# 159        99           50.5    709  7.2  14.2    75    3     0           8
# 143       116           59.5    987  8.5  14.3    61   10     0          19
# 138       117           61.5   1024  8.8  14.2    76    9     1          11
# 154       110           63.6    722  6.6  10.3    57    4     1           6
# 87        321           57.0   1894  5.9  10.3    65   13     3          23
# 21        397           65.2   3280  8.3  12.7    74   30     4          11
# 9         469           64.6   3793  8.1  12.5    68   27     5          24
# 150        89           57.3    782  8.8  15.3    76    4     1          10
# 89        264           64.8   1887  7.1  11.0    75   11     3          28
# 94        263           48.3   1785  6.8  14.1    80   12     3          14
# 12        427           68.6   3629  8.5  12.4    86   25     5          12
# 20        425           64.7   3292  7.7  12.0    48   25     5          26
# 85        335           57.9   1917  5.7   9.9    52   11     4          14
# 86        246           62.2   1907  7.8  12.5    55   12     3          22
# 122       155           65.2   1181  7.6  11.7    71    6     2          17
# 126       153           62.1   1117  7.3  11.8    49    7     2          21
# 35        379           57.8   2894  7.6  13.2    71   16     5          35
# 59        371           60.9   2547  6.9  11.3    59   17     5          20
# 41        369           60.7   2794  7.6  12.5    76   18     5          23
# 1         662           70.7   4779  7.2  10.2    89   38     9          13
# 142       220           50.5    989  4.5   8.9    52    5     3          16
# 145       141           68.1    942  6.7   9.8    42    3     2          10
# 134       140           56.4   1059  7.6  13.4    67    6     2           6
# 132       139           51.8   1074  7.7  14.9    74    5     2          23
# 13        417           64.0   3567  8.6  13.4    88   32     6           9
#
#      QBRating  AttemptsPerINT  INTModYards  INTModYardsPerAtt  AttemptsPerSack
# 159     120.7             inf          709               7.16            13.38
# 143     159.4             inf          987               8.51             7.11
# 138     158.7      117.000000          974               8.32            11.64
# 154     129.0      110.000000          672               6.11            19.33
# 87      118.1      107.000000         1744               5.43            14.96
# 21      157.6       99.200000         3080               7.76            37.09
# 9       149.4       93.800000         3543               7.55            20.54
# 150     143.7       89.000000          732               8.22             9.90
# 89      136.3       88.000000         1737               6.58            10.43
# 94      118.1       87.700000         1635               6.22            19.79
# 12      157.0       85.400000         3379               7.91            36.58
# 20      146.8       85.000000         3042               7.16            17.35
# 85      114.4       83.800000         1717               5.13            24.93
# 86      141.0       82.000000         1757               7.14            12.18
# 122     139.4       77.500000         1081               6.97            10.12
# 126     135.9       76.500000         1017               6.65             8.29
# 35      133.2       75.800000         2644               6.98            11.83
# 59      131.0       74.200000         2297               6.19            19.55
# 41      137.7       73.800000         2544               6.89            17.04
# 1       147.6       73.600000         4329               6.54            51.92
# 142      93.0       73.300000          839               3.81            14.75
# 145     128.4       70.500000          842               5.97            15.10
# 134     131.3       70.000000          959               6.85            24.33
# 132     125.7       69.500000          974               7.01             7.04
# 13      158.3       69.500000         3267               7.83            47.33

# %% [markdown]
# # SEC Data

# %%
sec_df = df[df['Conference'] == 'SEC'].reset_index(drop=True)

# %%
sec_df
# Out:
#                 Player  Team        TeamName TeamColor Conference  \
# 0       Tua Tagovailoa   ALA         Alabama   #9e1b32        SEC
# 1        Jordan Ta'amu  MISS        Ole Miss   #14213D        SEC
# 2            Drew Lock   MIZ        Missouri   #F1B82D        SEC
# 3         Jake Bentley    SC  South Carolina   #000000        SEC
# 4         Kyle Shurmur   VAN      Vanderbilt   #866d4b        SEC
# 5          Kellen Mond  TA&M       Texas A&M   #500000        SEC
# 6           Joe Burrow   LSU             LSU   #461D7C        SEC
# 7      Jarrett Stidham   AUB          Auburn   #0C2340        SEC
# 8           Jake Fromm   UGA         Georgia   #BA0C2F        SEC
# 9       Feleipe Franks   FLA         Florida   #0021A5        SEC
# 10  Jarrett Guarantano  TENN       Tennessee   #FF8200        SEC
# 11        Terry Wilson    UK        Kentucky   #0033a0        SEC
# 12     Nick Fitzgerald  MSST      Miss State   #660000        SEC
# 13           Ty Storey   ARK        Arkansas   #9D2235        SEC
#
#     Completions  Attempts  CompletionPct  Yards   YPA   YPC  Long  TDs  INTs  \
# 0           245       355           69.0   3966  11.2  16.2    81   43     6
# 1           266       418           63.6   3918   9.4  14.7    84   19     8
# 2           275       437           62.9   3498   8.0  12.7    86   28     8
# 3           240       388           61.9   3171   8.2  13.2    89   27    14
# 4           254       406           62.6   3130   7.7  12.3    75   24     6
# 5           238       415           57.3   3107   7.5  13.1    69   24     9
# 6           219       379           57.8   2894   7.6  13.2    71   16     5
# 7           224       369           60.7   2794   7.6  12.5    76   18     5
# 8           206       306           67.3   2749   9.0  13.3    75   30     6
# 9           188       322           58.4   2457   7.6  13.1    65   24     6
# 10          153       246           62.2   1907   7.8  12.5    55   12     3
# 11          180       268           67.2   1889   7.0  10.5    54   11     8
# 12          145       281           51.6   1767   6.3  12.2    84   16     9
# 13          143       250           57.2   1584   6.3  11.1    57   11    10
#
#     SacksTaken  QBRating  AttemptsPerINT  INTModYards  INTModYardsPerAtt  \
# 0           13     199.5            59.2         3666              10.33
# 1           29     153.5            52.2         3518               8.42
# 2           13     147.7            54.6         3098               7.09
# 3           20     146.3            27.7         2471               6.37
# 4           21     143.9            67.7         2830               6.97
# 5           34     135.0            46.1         2657               6.40
# 6           35     133.2            75.8         2644               6.98
# 7           23     137.7            73.8         2544               6.89
# 8           16     171.2            51.0         2449               8.00
# 9           15     143.3            53.7         2157               6.70
# 10          22     141.0            82.0         1757               7.14
# 11          28     134.0            33.5         1489               5.56
# 12          25     116.8            31.2         1317               4.69
# 13          19     116.9            25.0         1084               4.34
#
#     AttemptsPerSack
# 0             28.31
# 1             15.41
# 2             34.62
# 3             20.40
# 4             20.33
# 5             13.21
# 6             11.83
# 7             17.04
# 8             20.12
# 9             22.47
# 10            12.18
# 11            10.57
# 12            12.24
# 13            14.16

# %%
df['Team']['TENN']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-f13d89055d34> in <module>
# ----> 1 df['Team']['TENN']
#
# ~\Anaconda3\envs\mainenv\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~\Anaconda3\envs\mainenv\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'TENN'

# %%
sec_df.to_csv(r'sec_qbs_2018.csv')
